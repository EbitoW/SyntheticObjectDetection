# %%
# %cd yolov3
# Out:
# /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3

# %%
# Train YOLOv5s on COCO128 for 3 epochs
#!python train.py --img 640 --batch 16 --epochs 3 --data coco128.yaml --weights yolov5s.pt --cache
#!python train.py --img 640 --epochs 3 --data coco128.yaml --weights yolov5s.pt
#--weights '' --cfg yolov5s.yaml


# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 15965, done.
# remote: Counting objects: 100% (134/134), done.
# remote: Compressing objects: 100% (68/68), done.
# Command 'git fetch ultralytics' timed out after 5 seconds
# ...

# %%
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml --img 640


# /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp/weights/best.pt
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Combined 300r, 300s

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml --weights '' --cfg yolov3-tiny.yaml

#!python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2665 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp6/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml --img 640
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp6/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %%
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp6/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp6/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
#                  Class     Images  Instances          P          R      mAP50
# ...

# %%
# Verbose

# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp6/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml --img 640 --batch-size 16 --verbose
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_300s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp6/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=True, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
#                  Class     Images  Instances          P          R      mAP50
# ...

# %% [markdown]
# # Combined: 300r, 600s

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_600s_Random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_600s_Random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2665 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp10/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_600s_Random_1.yaml --img 640
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_600s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp10/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Combined: 300r, 1200s

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_1200s_Random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_1200s_Random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2665 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp11/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_300r_1200s_Random_1.yaml --img 640
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_300r_1200s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp11/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
#                  Class     Images  Instances          P          R      mAP50
# ...

# %% [markdown]
# # Real: 300r

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_300_100_500.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_300_100_500.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2665 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
# ...

# %%
# Validate on test set
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp9/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_300_100_500.yaml --img 640
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_300_100_500.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp9/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
#                  Class     Images  Instances          P          R      mAP50
# ...

# %%
# Validate on test set, batch size 16, v2
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp9/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_300_100_500.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_300_100_500.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp9/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Combined: 1500r, 300s

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_300s_Random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_300s_Random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2665 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# ?? exp12
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp12/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_300s_Random_1.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_300s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp12/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
#                  Class     Images  Instances          P          R      mAP50
# ...

# %% [markdown]
# # Combined: 1500r, 600s

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_600s_Random_1.yaml --weights '' --cfg yolov3-tiny.yaml

# %%
# ?? exp 13
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp13/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_600s_Random_1.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_600s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp13/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Combined: 1500r, 1200s

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_1200s_Random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_1200s_Random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2665 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# runs/train/exp15
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp15/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_1200s_Random_1.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_combined_1500r_1200s_Random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp15/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Real: 1500r

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_1500_500_500.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_1500_500_500.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2665 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# runs/train/exp16
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp16/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_1500_500_500.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_1500_500_500.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp16/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Real: 60

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_60_20_500.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_60_20_500.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 15 (delta 4), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), 28.63 KiB | 94.00 KiB/s, done.
# ...

# %%
# runs/train/exp17
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp17/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_60_20_500.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_60_20_500.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp17/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Real: 12

# %%
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_12_4_500.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_12_4_500.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2667 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# ...

# %%
# runs/train/exp21
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp21/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_real_12_4_500.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_real_12_4_500.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp21/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Synthetic 1200

# %%
# dataset_synthetic_1200_400_500_random_1
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_synthetic_1200_400_500_random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_synthetic_1200_400_500_random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2667 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# runs/train/exp18
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp18/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_synthetic_1200_400_500_random_1.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_synthetic_1200_400_500_random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp18/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Synthetic 600

# %%
# dataset_synthetic_600_200_500_random_1
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_synthetic_600_200_500_random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_synthetic_600_200_500_random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2667 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# runs/train/exp19
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp19/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_synthetic_600_200_500_random_1.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_synthetic_600_200_500_random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp19/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...

# %% [markdown]
# # Synthetic 300

# %%
# dataset_synthetic_300_100_500_random_1
# !python3 train.py --img 640 --epochs 50 --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_synthetic_300_100_500_random_1.yaml --weights '' --cfg yolov3-tiny.yaml
# Out:
# train: weights=, cfg=yolov3-tiny.yaml, data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_synthetic_300_100_500_random_1.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=50, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv3 is out of date by 2667 commits. Use `git pull ultralytics master` or `git clone https://github.com/ultralytics/yolov5` to update.
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# ...

# %%
# runs/train/exp20
# !python3 val.py --task test --weights /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp20/weights/best.pt --data /home/tobie/Documents/Afstudeerproject\ bachelor\ Informatica/Model_analysis/Yaml_files/dataset_synthetic_300_100_500_random_1.yaml --img 640 --batch-size 16
# Out:
# val: data=/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis/Yaml_files/dataset_synthetic_300_100_500_random_1.yaml, weights=['/home/tobie/Documents/Afstudeerproject bachelor Informatica/Model_analysis_Yolov3/yolov3/runs/train/exp20/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to '/home/tobie/Documents/Afstudeerproject': No such file or directory
# YOLOv3 🚀 2023-6-15 Python-3.10.6 torch-2.0.0+cu117 CPU
#
# Fusing layers...
# yolov3-tiny summary: 38 layers, 8669002 parameters, 0 gradients, 12.9 GFLOPs
# test: Scanning /home/tobie/Documents/Afstudeerproject bachelor Informatica/Model
# ...
